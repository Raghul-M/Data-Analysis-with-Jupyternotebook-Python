# %% [markdown]
# <b>Loading Necessary Libraries</b>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import pandas as pd

# %% [markdown]
# <b>Basic Graph<b>

# %%
x=[0,1,2,3,4]
y=[0,2,4,6,8]

#plt.plot(x,y,label='2x',color="green",linewidth=5,linestyle="--",marker='.',markersize=20,markeredgecolor="b")

#Resize your graph 

plt.figure(figsize=(5,2),dpi=200)


#Shorthand

plt.plot(x,y,'g*--',label='2x')

plt.title('Our First Graph',fontdict ={'fontname':'Comic Sans MS','fontsize':10})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
#plt.xticks([0,1,2,3,4]) #x-axis values
#plt.yticks([0,2,4,6,8,10]) #y-axis values



# Line Number 2

x2=np.arange(0,4.5,0.5)
#plot remainder of the graph
plt.plot(x2[:6],x2[:6]**2,'r',label="new")
#plt.plot(x2,x2**2,'c-',label="3x")

#Save fig

plt.savefig('myfig.png',dpi=300) #dpi 300 for high resolution

plt.legend()
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
labels=['A','B','C']
values=[1,4,6]



bars=plt.bar(labels,values)

#bars[0].set_hatch('/')
#bars[2].set_hatch('*')

patterns =['/','.','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.show()

# %% [markdown]
# ### Real World Examples

# %% [markdown]
# ### Line chart

# %%
gas = pd.read_csv(r"C:\Users\ER258MG\Downloads\matplotlib_tutorial-master\matplotlib_tutorial-master\gas_prices.csv")
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.figure(figsize=(8,5))
plt.title('Gas Price USA Vs Canada')
plt.plot(gas.Year,gas.USA,label="USA")#
plt.plot(gas.Year,gas['Canada'],label="Canada")#,
plt.plot(gas.Year,gas['South Korea'],label="S-Korea")
#plt.yticks([0,1,2,3,4,5])
formatter = ticker.FuncFormatter(lambda x, pos: "{:.0f}".format(x))
plt.gca().xaxis.set_major_formatter(formatter)
xticks = (gas.Year[::3])
plt.xlabel('Year')
plt.ylabel('US Dollars')
plt.legend()
plt.show()

# %%
for country in gas:
    if country !="Year":     
        print(country)
# Out:
# Australia
# Canada
# France
# Germany
# Italy
# Japan
# Mexico
# South Korea
# UK
# USA

# %%
plt.figure(figsize=(8,5))
for country in gas:
    if country !="Year":
        formatter = ticker.FuncFormatter(lambda x, pos: "{:.0f}".format(x))
        plt.gca().xaxis.set_major_formatter(formatter)
        plt.gca().set_facecolor('lightgray')
        xticks = (gas.Year[::3].tolist()+[2011])
        plt.plot(gas.Year,gas[country],marker='.',label=country)

plt.legend()

plt.xlabel('Year')
plt.ylabel('US Dollars')
plt.show()
plt.savefig("chart3.png",dpi=300)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

plt.figure(figsize=(8, 8))

for country in gas:
    if country != "Year":
        formatter = ticker.FuncFormatter(lambda x, pos: "{:.0f}".format(x))
        plt.gca().xaxis.set_major_formatter(formatter)
        #plt.gca().set_facecolor('lightgray')
        xticks = (gas.Year[::3].tolist() + [2011])
        plt.plot(gas.Year, gas[country], marker='.', label=country)

plt.legend()
plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.savefig("chartnew1.png", dpi=300)
plt.show()

# %% [markdown]
# ### Loading Fifa data

# %%
fifa=pd.read_csv(r"C:\Users\ER258MG\Downloads\matplotlib_tutorial-master\matplotlib_tutorial-master\fifa_data.csv")

# %%
fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ### Histograms

# %%
bins=[40,50,60,70,80,90,100]

plt.hist(fifa.Overall,bins,color="#abcdef")
xticks=(bins)
plt.title("Skill level of Players in FIFA 2018 ")
plt.xlabel("Skill level")
plt.ylabel("Number of Players")
plt.show()

# %% [markdown]
# ### PIE Charts

# %%
#for index,row in enumerate(fifa):
   # print(index,row)

# %%
fifa['Preferred Foot']
# Out:
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18207, dtype: object

# %%
left = fifa.loc[fifa['Preferred Foot'] == "Left"] .count()[0]
right = fifa.loc[fifa['Preferred Foot'] == "Right"] .count()[0]

# %%
left
# Out:
# 4211

# %%
right
# Out:
# 13948

# %%
labels = ['Left','Right']
colors = ['#abcdef',"#E6AB9F"]
plt.pie([left,right],labels=labels,colors=colors,autopct='%.2f %%')
plt.title("Foot prefernce of FIFA Players")
plt.show()

# %% [markdown]
# ### PIE Chart 2

# %%
fifa.Weight
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
fifa.Weight =[int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]

# %%
fifa.Weight[0]
# Out:
# 159.0

# %%
light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]
plt.style.use('ggplot')

# %%
weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explode = (.4,.2,0,0,0)

plt.title('Weight of Professional Soccer Players (lbs)')

plt.pie(weights, labels=label, explode=explode, pctdistance=0.8,autopct='%.2f %%')
plt.show()

# %% [markdown]
# ### Box and Whiskers Chart

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
barcelona=fifa.loc[fifa.Club== 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == "Real Madrid"]['Overall']
revs = fifa.loc[fifa.Club == "New England Revolution"]['Overall']

# %%
#plt.figure= (figsize=(5,8))
plt.figure(figsize=(5,8))
plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

plt.style.use('default')
labels=['FC Barcelona','Real Madrid','NE Revolution']#
plt.boxplot([barcelona,madrid,revs],labels=labels)
plt.show()
