# %% [markdown]
# Scraping Top 250 Movies data from IMDB website

# %%
from bs4 import BeautifulSoup
import requests
try:
    response=requests.get("https://www.imdb.com/chart/top")
    soup=BeautifulSoup(response.text,'html.parser')
    #print(soup)
    movies=soup.find('tbody',class_="lister-list").find_all("tr")
    for movie in movies:
        #print(movie)
        movie_rank=movie.find('td',class_="titleColumn").get_text(strip=True).split('.')[0]
        movie_name=movie.find('td',class_="titleColumn").a.text
        movie_rating=movie.find('td',class_="ratingColumn imdbRating").strong.text
        movie_year=movie.find('td',class_="titleColumn").span.text#replace('(',"")
        #movie_year=movie_year.replace(')',"")
        print(movie_rank, movie_name, movie_year, movie_rating)
       
        
except Exception as e:
    print(e)
# Out:
# 1 The Shawshank Redemption (1994) 9.2
# 2 The Godfather (1972) 9.2
# 3 The Dark Knight (2008) 9.0
# 4 The Godfather Part II (1974) 9.0
# 5 12 Angry Men (1957) 9.0
# 6 Schindler's List (1993) 8.9
# 7 The Lord of the Rings: The Return of the King (2003) 8.9
# 8 Pulp Fiction (1994) 8.8
# 9 The Lord of the Rings: The Fellowship of the Ring (2001) 8.8
# 10 Il buono, il brutto, il cattivo (1966) 8.8
# 11 Forrest Gump (1994) 8.8
# 12 Fight Club (1999) 8.7
# 13 The Lord of the Rings: The Two Towers (2002) 8.7
# 14 Inception (2010) 8.7
# 15 The Empire Strikes Back (1980) 8.7
# 16 The Matrix (1999) 8.7
# 17 GoodFellas (1990) 8.7
# 18 One Flew Over the Cuckoo's Nest (1975) 8.6
# 19 Se7en (1995) 8.6
# 20 Shichinin no samurai (1954) 8.6
# 21 It's a Wonderful Life (1946) 8.6
# 22 The Silence of the Lambs (1991) 8.6
# 23 Cidade de Deus (2002) 8.6
# 24 Saving Private Ryan (1998) 8.6
# 25 La vita è bella (1997) 8.6
# 26 Interstellar (2014) 8.6
# 27 The Green Mile (1999) 8.6
# 28 Star Wars (1977) 8.5
# ...

# %%
from bs4 import BeautifulSoup
import requests,openpyxl

excel=openpyxl.Workbook()
sheet=excel.active
sheet.title="Top 250 Movie Lists"
sheet.append(['Rank','Movie Name','Year of Release','IMDB Rating'])



try:
    response=requests.get("https://www.imdb.com/chart/top")
    soup=BeautifulSoup(response.text,'html.parser')
    #print(soup)
    movies=soup.find('tbody',class_="lister-list").find_all("tr")
    for movie in movies:
        #print(movie)
        movie_rank=movie.find('td',class_="titleColumn").get_text(strip=True).split('.')[0]
        movie_name=movie.find('td',class_="titleColumn").a.text
        movie_rating=movie.find('td',class_="ratingColumn imdbRating").strong.text
        movie_year=movie.find('td',class_="titleColumn").span.text.replace('(',"")
        movie_year=movie_year.replace(')',"")
        #print(movie_rank, movie_name, movie_year, movie_rating)
        sheet.append([movie_rank, movie_name, movie_year, movie_rating])
       
        
except Exception as e:
    print(e)
    
excel.save("Movies1.xlsx")

# %% [markdown]
# Example : Top 50 Adventures Movies

# %%
from bs4 import BeautifulSoup
import requests,openpyxl

excel=openpyxl.Workbook()
sheet=excel.active
sheet.title="Top 250 Movie Lists"
sheet.append(['S.No','Movie Name','Year of Release','IMDB Rating','Story','Director','Gross'])



try:
    response=requests.get("https://www.imdb.com/search/title/?genres=adventure&sort=user_rating,desc&title_type=feature&num_votes=25000,&pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=f11158cc-b50b-4c4d-b0a2-40b32863395b&pf_rd_r=7SXGAV2CNFEKEJZF3KZ6&pf_rd_s=right-6&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_gnr_2")
    soup=BeautifulSoup(response.text,'html.parser')
    movies=soup.find('div',class_="lister-list").find_all("div",class_="lister-item")
    for movie in movies:
        index=movie.find("h3").find('span',class_="lister-item-index").get_text(strip=True)
        name=movie.find("h3").a.text
        year=movie.find("h3").find('span',class_="lister-item-year").text
        rating=movie.find('div',class_="ratings-imdb-rating").strong.text
        paragh=movie.find("p").findNext('p').get_text(strip=True)
        director=movie.find("p").findNext("p").findNext("p").a.text
        gross=movie.find("p",class_="sort-num_votes-visible").find_all("span")[-1].get_text()
       # print(index, name, year, rating, director, gross)
       # print(paragh)
        
        sheet.append([index, name, year, rating, paragh, director, gross])
       
        
except Exception as e:
    print(e)
    
excel.save("Action.xlsx")

# %% [markdown]
# Quotes Scraper

# %%
from bs4 import BeautifulSoup
import requests

response=requests.get("https://quotes.toscrape.com/")
soup=BeautifulSoup(response.text,'html.parser')
quotes=soup.find('div',class_="quote")
for i in quotes:
    print('-'*50)
    content = i.find('span',class_='text').text
    print(content)
    author = i.find('small',class_='author').text
    print(author)
    print('-'*50)
# Out:
# --------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29320\711663040.py in <module>
#       7 for i in quotes:
#       8     print('-'*50)
# ----> 9     content = i.find('span',class_='text').text
#      10     print(content)
#      11     author = i.find('small',class_='author').text
#
# TypeError: find() takes no keyword arguments

# %%
quotes
# Out:
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# </div>

# %%
for i in quotes:
    print(i)
# Out:
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#
#
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
#
#
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>

# %%
a=10
b=40
c=130
if(a>b): 
    print("a is greater")
elif(b<c):
    print("c is greater")
else:
    print("b is greater")
# Out:
# c is greater

# %%
# Out:
# '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”'

# %%
quotes
# Out:
# [<div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#  <a class="tag" href="/tag/world/page/1/">world</a>
#  </div>
#  </div>,
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“It is our choices, Harry, that show what we truly are, far more than our abilities.”</span>
# ...

# %%
for i in quotes:
    print('-------')
    print(i)
    print('-------')
# Out:
# -------
#
#
# -------
# -------
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# -------
# -------
#
#
# -------
# -------
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# -------
# -------
#
#
# -------
# -------
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>
# -------
# -------
#
#
# -------
